# %% [markdown]
# This notebook is to explore some inconsistencies in the tokenizers funcionality. For the token alingment I need the methids words_id() and words_to_chars() that are not working correctly for Llama and not working for Mistral. Apparently it depends on the tokenizer type and there is a open issue in Github

# %%
from transformers import AutoTokenizer
import transformers
transformers.tokenization_utils_base.BatchEncoding
# Out:
# transformers.tokenization_utils_base.BatchEncoding

# %%
#! pip install sentencepiece
#! pip install protobuf
print(transformers.__version__)
import sentencepiece
print(sentencepiece.__version__)
# Out:
# 4.44.2
# 0.2.0

# %%
text = 'this is an example of a string'
def compute_words(tokenizer, text):
    
    text_tokenized = tokenizer(
                        text,
                        add_special_tokens=True,
                        return_offsets_mapping=True,
                    )
    print(text_tokenized['offset_mapping'])
    num_words = max([x if x is not None else 0 for x in text_tokenized.word_ids()])
    words = []
    for j in range(num_words):
        #print(type(text_tokenized))
        chars = text_tokenized.word_to_chars(j)
        print(chars)
        chars_next = text_tokenized.word_to_chars(j+1)
        words.append(text[chars[0] : chars_next[0]].strip().lower())
    if num_words > 0:
        words.append(text[chars_next[0] : ].strip().lower())
    else:
        words.append(text.strip().lower())
    return words

# %%
print('----------------')
base_model = "mistralai/Mistral-7B-v0.3"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, use_fast=True
            )
tokenizer._tokenizer.pre_tokenizer.split = False

print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
# Out:
# ----------------
# mistralai/Mistral-7B-v0.3
# <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>
# [(0, 0), (0, 4), (4, 7), (7, 10), (10, 18), (18, 21), (21, 23), (23, 30)]
# ['this is an example of a string']

# %%
print('----------------')
base_model = "meta-llama/Meta-Llama-3-8B"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, trust_remote_code=True
            )
print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
print('----------------')
base_model = "meta-llama/Meta-Llama-3-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, trust_remote_code=True
            )
print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
print('----------------')
base_model = "mistralai/Mistral-7B-v0.3"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, use_fast=True
            )
print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
print('----------------')
base_model='roberta-base'
tokenizer = transformers.RobertaTokenizerFast.from_pretrained(base_model, add_prefix_space=True)
print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
print('----------------')
base_model="t5-small"
tokenizer = AutoTokenizer.from_pretrained(
            base_model, cache_dir="./cache/models", model_max_length=2048
        )
print(base_model)
print(type(tokenizer))
words = compute_words(tokenizer, text)
print(words)
print('----------------')
# Out:
# ----------------
# meta-llama/Meta-Llama-3-8B
# <class 'transformers.tokenization_utils_fast.PreTrainedTokenizerFast'>
# tensor([[[ 0,  0],
#          [ 0,  0],
#          [ 4,  4],
#          [ 7,  7],
#          [10, 10],
#          [18, 18],
#          [21, 21],
#          [23, 23]]])
# CharSpan(start=0, end=0)
# CharSpan(start=4, end=4)
# CharSpan(start=7, end=7)
# CharSpan(start=10, end=10)
# CharSpan(start=18, end=18)
# CharSpan(start=21, end=21)
# ['this', 'is', 'an', 'example', 'of', 'a', 'string']
# ----------------
# meta-llama/Meta-Llama-3-8B-Instruct
# <class 'transformers.tokenization_utils_fast.PreTrainedTokenizerFast'>
# tensor([[[ 0,  0],
#          [ 0,  0],
#          [ 4,  4],
#          [ 7,  7],
#          [10, 10],
#          [18, 18],
#          [21, 21],
#          [23, 23]]])
# CharSpan(start=0, end=0)
# CharSpan(start=4, end=4)
# CharSpan(start=7, end=7)
# CharSpan(start=10, end=10)
# CharSpan(start=18, end=18)
# CharSpan(start=21, end=21)
# ['this', 'is', 'an', 'example', 'of', 'a', 'string']
# ----------------
# mistralai/Mistral-7B-v0.3
# <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>
# tensor([[[ 0,  0],
#          [ 0,  4],
#          [ 4,  7],
#          [ 7, 10],
#          [10, 18],
#          [18, 21],
#          [21, 23],
#          [23, 30]]])
# ['this is an example of a string']
# ----------------
# /home/alop/miniconda3/envs/shared_task_env/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# roberta-base
# <class 'transformers.models.roberta.tokenization_roberta_fast.RobertaTokenizerFast'>
# tensor([[[ 0,  0],
#          [ 0,  4],
#          [ 5,  7],
#          [ 8, 10],
#          [11, 18],
#          [19, 21],
#          [22, 23],
#          [24, 30],
#          [ 0,  0]]])
# CharSpan(start=0, end=4)
# CharSpan(start=5, end=7)
# CharSpan(start=8, end=10)
# CharSpan(start=11, end=18)
# CharSpan(start=19, end=21)
# CharSpan(start=22, end=23)
# ['this', 'is', 'an', 'example', 'of', 'a', 'string']
# ----------------
# t5-small
# <class 'transformers.models.t5.tokenization_t5_fast.T5TokenizerFast'>
# tensor([[[ 0,  4],
#          [ 5,  7],
#          [ 8, 10],
#          [11, 18],
#          [19, 21],
#          [22, 23],
#          [22, 23],
#          [24, 30],
#          [ 0,  0]]])
# CharSpan(start=0, end=4)
# CharSpan(start=5, end=7)
# CharSpan(start=8, end=10)
# CharSpan(start=11, end=18)
# CharSpan(start=19, end=21)
# CharSpan(start=22, end=23)
# ['this', 'is', 'an', 'example', 'of', 'a', 'string']
# ----------------

# %%
print(print(transformers.__version__))
print('----------------')
base_model = "meta-llama/Meta-Llama-3-8B"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, trust_remote_code=True
            )
print(base_model)
print(type(tokenizer))
print('----------------')
base_model = "meta-llama/Meta-Llama-3-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, trust_remote_code=True
            )
print(base_model)
print(type(tokenizer))
print('----------------')
base_model = "mistralai/Mistral-7B-v0.3"
tokenizer = AutoTokenizer.from_pretrained(
                base_model, trust_remote_code=True
            )
print(base_model)
print(type(tokenizer))
print('----------------')
base_model='roberta-base'
tokenizer = transformers.RobertaTokenizerFast.from_pretrained(base_model, add_prefix_space=True)
print(base_model)
print(type(tokenizer))
print('----------------')
base_model="t5-small"
tokenizer = AutoTokenizer.from_pretrained(
            base_model, cache_dir="./cache/models", model_max_length=2048
        )

print(base_model)
print(type(tokenizer))
print('----------------')
# Out:
# 4.44.2
# None
# ----------------
# meta-llama/Meta-Llama-3-8B
# <class 'transformers.tokenization_utils_fast.PreTrainedTokenizerFast'>
# ----------------
# meta-llama/Meta-Llama-3-8B-Instruct
# <class 'transformers.tokenization_utils_fast.PreTrainedTokenizerFast'>
# ----------------
# mistralai/Mistral-7B-v0.3
# <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>
# ----------------
# roberta-base
# <class 'transformers.models.roberta.tokenization_roberta_fast.RobertaTokenizerFast'>
# ----------------
# t5-small
# <class 'transformers.models.t5.tokenization_t5_fast.T5TokenizerFast'>
# ----------------
